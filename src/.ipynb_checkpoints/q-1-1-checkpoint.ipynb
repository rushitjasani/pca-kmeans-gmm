# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("../input_data/intrusion_detection/data.csv")
Y = df.xAttack
X = df.drop(['xAttack'],axis=1)
X = (X - X.mean())/X.std()
X.head()
# Out:
#    duration   service  src_bytes  dst_bytes       hot  num_failed_logins  \
# 0 -0.110249 -0.734168  -0.007679  -0.004919 -0.095075          -0.027023
# 1 -0.110249  0.784428  -0.007737  -0.004919 -0.095075          -0.027023
# 2 -0.110249  1.088148  -0.007762  -0.004919 -0.095075          -0.027023
# 3 -0.110249 -0.430448  -0.007723  -0.002891 -0.095075          -0.027023
# 4 -0.110249 -0.430448  -0.007728  -0.004814 -0.095075          -0.027023
#
#    num_compromised  num_root  num_file_creations  num_access_files  \
# 0        -0.011664 -0.012385            -0.02618         -0.041221
# 1        -0.011664 -0.012385            -0.02618         -0.041221
# 2        -0.011664 -0.012385            -0.02618         -0.041221
# 3        -0.011664 -0.012385            -0.02618         -0.041221
# 4        -0.011664 -0.012385            -0.02618         -0.041221
#
#              ...             dst_host_count  dst_host_srv_count  \
# 0            ...                  -0.324062           -0.818887
# 1            ...                   0.734340           -1.035684
# 2            ...                   0.734340           -0.809854
# 3            ...                  -1.533663            1.258749
# 4            ...                   0.734340            1.258749
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0               -0.782364               -0.280281
# 1               -1.161026                2.736841
# 2               -0.938283               -0.174417
# 3                1.066397               -0.439076
# 4                1.066397               -0.439076
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                     0.069972                    -0.289102
# 1                     2.367728                    -0.289102
# 2                    -0.480195                    -0.289102
# 3                    -0.383107                     0.066252
# 4                    -0.480195                    -0.289102
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0             -0.639529                 -0.624868             -0.224532
# 1             -0.639529                 -0.624868             -0.387633
# 2              1.608753                  1.618949             -0.387633
# 3             -0.572081                 -0.602430             -0.387633
# 4             -0.639529                 -0.624868             -0.387633
#
#    dst_host_srv_rerror_rate
# 0                 -0.376386
# 1                 -0.376386
# 2                 -0.376386
# 3                 -0.345083
# 4                 -0.376386
#
# [5 rows x 29 columns]

# %%
pca = PCA(.90)
principalComponents = pca.fit(X)
X_red = pca.transform(X)
X_new = pd.DataFrame( X_red,columns=[ "pc"+str(i) for i in xrange(X_red.shape[1]) ] )

# %%
finalDf = pd.concat([X_new, df[['xAttack']]], axis = 1)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.23246105, 0.16724199, 0.07534424, 0.065137  , 0.05097278,
#        0.04634776, 0.03924108, 0.0354739 , 0.03500152, 0.03448813,
#        0.03434693, 0.03244503, 0.02727977, 0.02485247])

# %%
cov_x = np.cov(X.T)
cov_x.shape
# Out:
# (29, 29)

# %%
U,S,V = np.linalg.svd(cov_x)
S_sum = float(np.sum(S))

# %%
running_sum = 0
num_of_comp = 0
for i in xrange(len(S)):
    running_sum += S[i]
    if running_sum  / S_sum  >= 0.90:
        num_of_comp = i+1
        break
print num_of_comp
# Out:
# 14

# %%
print U.shape
# Out:
# (29, 29)

# %%
U_red = U[:,:num_of_comp]
print U_red.shape
# Out:
# (29, 14)

# %%
Z = np.matmul(U_red.T, X.T)
Z = Z.T
Z_new = pd.DataFrame( Z,columns=[ "pc"+str(i) for i in xrange(Z.shape[1]) ] )

# %%
X_new.head()
# Out:
#         pc0       pc1       pc2       pc3       pc4       pc5       pc6  \
# 0 -1.008898 -0.272002  0.029599 -0.150049 -0.259691 -0.578092 -0.058920
# 1  0.495835  1.120904  0.211957 -1.340935  1.399760 -2.614645 -1.432528
# 2  3.802320 -1.248093  0.058765 -0.434411 -0.394422  0.108575  0.140224
# 3 -2.103182 -1.050183 -0.037603  0.002242 -0.858467  0.242828  0.029154
# 4 -1.891740 -0.881353 -0.156239  1.170184 -0.583162 -0.268427 -0.042166
#
#         pc7       pc8       pc9      pc10      pc11      pc12      pc13
# 0 -0.174519  0.269306  0.034294  0.066373 -0.280442  0.057627 -0.477103
# 1  0.272442 -0.051265  0.011499  0.163504 -0.214390  0.061687 -0.061050
# 2  0.172885 -0.078086  0.006332 -0.009409 -0.119713  0.000965  0.278396
# 3  0.230058 -0.034821 -0.003268 -0.001687 -0.053330  0.178821 -0.776296
# 4  0.312499 -0.093507 -0.006820 -0.055598 -0.069313  0.052597  0.067159

# %%
Z_new.head()
# Out:
#         pc0       pc1       pc2       pc3       pc4       pc5       pc6  \
# 0  1.008898 -0.272002  0.029599  0.150049 -0.259691  0.578092  0.058920
# 1 -0.495835  1.120904  0.211957  1.340935  1.399760  2.614645  1.432528
# 2 -3.802320 -1.248093  0.058765  0.434411 -0.394422 -0.108575 -0.140224
# 3  2.103182 -1.050183 -0.037603 -0.002242 -0.858467 -0.242828 -0.029154
# 4  1.891740 -0.881353 -0.156239 -1.170184 -0.583162  0.268427  0.042166
#
#         pc7       pc8       pc9      pc10      pc11      pc12      pc13
# 0  0.174519  0.269306  0.034294  0.066373 -0.280442 -0.057627 -0.477103
# 1 -0.272442 -0.051265  0.011499  0.163504 -0.214390 -0.061687 -0.061050
# 2 -0.172885 -0.078086  0.006332 -0.009409 -0.119713 -0.000965  0.278396
# 3 -0.230058 -0.034821 -0.003268 -0.001687 -0.053330 -0.178821 -0.776296
# 4 -0.312499 -0.093507 -0.006820 -0.055598 -0.069313 -0.052597  0.067159
